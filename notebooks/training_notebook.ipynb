# %% [markdown]
# # HearCue Training Notebook
# Use this notebook to explore audio features and train the CNN.

# %%
from hearcue.model.train_cnn import train
model_path = train('data/processed', epochs=1, batch_size=4, output_dir='hearcue/model')
model_path
