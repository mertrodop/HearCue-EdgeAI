# %% [markdown]
# # HearCue Evaluation Notebook
# Visualize predictions, F1 metrics, and human study surveys.

# %%
import pandas as pd
from hearcue.evaluation.compute_f1 import macro_f1
df = pd.read_csv('predictions.csv')
macro_f1(df['y_true'], df['y_pred'])
